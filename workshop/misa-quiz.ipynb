# %% [markdown]
# # My MISA quiz
# Save a copy in Drive before editing. Follow the workshop guide and run one milestone at a time. Each code cell is a complete version.
# Choose a letter when prompted. Rerunning a milestone resets its scores. This notebook needs no extra packages or local Git.

# %% [markdown]
# ## 00-start
#
# Read the [matching lesson](https://github.com/yanicells/misa-python-workshop/blob/main/web/src/content/docs/setup.mdx). Edit this cell as the guide explains.

# %%
print("Your MISA quiz starts here.")

# %% [markdown]
# ## 01-welcome
#
# Read the [matching lesson](https://github.com/yanicells/misa-python-workshop/blob/main/web/src/content/docs/build/welcome.mdx). Edit this cell as the guide explains.

# %%
# Change the name to your own.
name = "Alex"
print("Hi, " + name + "!")
print("Let's find a MISA cluster you might enjoy.")

# %% [markdown]
# ## 02-question
#
# Read the [matching lesson](https://github.com/yanicells/misa-python-workshop/blob/main/web/src/content/docs/build/question.mdx). Edit this cell as the guide explains.

# %%
name = "Alex"
print("Hi, " + name + "!")
print("What would you like to help with?")
print("a. Build a small app")
print("b. Design a poster")
print("c. Plan an activity")

answer = input("Choose a, b, or c: ").strip().lower()
while answer not in ["a", "b", "c"]:
    print("Please type a, b, or c.")
    answer = input("Your choice: ").strip().lower()

if answer == "a":
    print("eServs earns 1 point.")
elif answer == "b":
    print("COMMS earns 1 point.")
else:
    print("Events earns 1 point.")
