# %% [markdown]
# # My MISA cluster quiz
#
# Save a copy in Drive before editing. Follow the workshop guide and run one milestone at a time. Each code cell is a complete version.
#
# Choose a letter when prompted. Rerunning a milestone resets its scores. This notebook needs no extra packages or local Git.

# %% [markdown]
# ## 00-start
#
# Read the [matching lesson](https://github.com/yanicells/misa-python-workshop/blob/main/web/src/content/docs/setup.mdx). This cell is the complete checkpoint version.

# %%
print("Your MISA quiz starts here.")

# %% [markdown]
# ## 01-welcome
#
# Read the [matching lesson](https://github.com/yanicells/misa-python-workshop/blob/main/web/src/content/docs/build/welcome.mdx). This cell is the complete checkpoint version.

# %%
print("Welcome to the MISA Cluster Finder!")
name = input("What should we call you? ")
print()
print("Hi, " + name + "!")
print("Answer a few questions to find MISA clusters you may enjoy.")

# %% [markdown]
# ## 02-question
#
# Read the [matching lesson](https://github.com/yanicells/misa-python-workshop/blob/main/web/src/content/docs/build/question.mdx). This cell is the complete checkpoint version.

# %%
print("Welcome to the MISA Cluster Finder!")
name = input("What should we call you? ")
print()
print("Hi, " + name + "!")
print("Answer a few questions to find MISA clusters you may enjoy.")
print()
print("Question 1 of 1")
print("What would you like to help with?")
print("a. Build a small app")
print("b. Design a poster")
print("c. Plan an activity")

answer = input("Your choice: ").strip().lower()
while answer not in ["a", "b", "c"]:
    print("Please type a, b, or c.")
    answer = input("Your choice: ").strip().lower()

if answer == "a":
    print("eServices is the closest match for that choice.")
elif answer == "b":
    print("Communications is the closest match for that choice.")
else:
    print("Events is the closest match for that choice.")
